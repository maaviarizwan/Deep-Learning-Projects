# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame([[8,8,4],[7,9,5],[6,10,6],[5,12,7]], columns=['cgpa','profile_score','lpa'])

# %%
df
# Out:
#    cgpa  profile_score  lpa
# 0     8              8    4
# 1     7              9    5
# 2     6             10    6
# 3     5             12    7

# %%
def initialize_parameters(layers_dims):
    np.random.seed(3)
    parameters = {}
    L = len(layers_dims)            # number of layers in the network

    for l in range(1, L):
        parameters['W' + str(l)] = np.ones((layers_dims[l], layers_dims[l-1])) * 0.1
        parameters['b' + str(l)] = np.zeros((layers_dims[l], 1))
    return parameters

# %%
initialize_parameters([2, 2, 1])
# Out:
# {'W1': array([[0.1, 0.1],
#         [0.1, 0.1]]),
#  'b1': array([[0.],
#         [0.]]),
#  'W2': array([[0.1, 0.1]]),
#  'b2': array([[0.]])}

# %%
def linear_forward(A_prev, W, b):
    Z = np.dot(W, A_prev) + b
    return Z

# %%
def L_layer_forward(X, parameters):
    A = X
    L = len(parameters) // 2 

    for l in range(1, L+1):
        A_prev = A
        Wl = parameters['W'+ str(l)]
        bl = parameters['b'+ str(l)]
        print("A"+str(l-1)+": ",A_prev)
        print("W"+str(l)+": ",Wl)
        print("b"+str(l)+": ",bl)
        print("--"*20)

        A = linear_forward(A_prev, Wl, bl)
        print("A"+str(l)+": ", A)

    return A, A_prev

# %%
X = df[['cgpa', 'profile_score']].values[0].reshape(2,1)
y = df[['lpa']].values[0][0]

parameters = initialize_parameters([2,2,1])

y_hat,A1 = L_layer_forward(X, parameters)
# Out:
# A0:  [[8]
#  [8]]
# W1:  [[0.1 0.1]
#  [0.1 0.1]]
# b1:  [[0.]
#  [0.]]
# ----------------------------------------
# A1:  [[1.6]
#  [1.6]]
# A1:  [[1.6]
#  [1.6]]
# W2:  [[0.1 0.1]]
# b2:  [[0.]]
# ----------------------------------------
# A2:  [[0.32]]

# %%
y_hat = y_hat[0][0]

# %%
def update_parameters(parameters, y, y_hat,A1,X):
    error = 0.001 * 2 * (y - y_hat.item())
    
    parameters['W2'][0][0] = parameters['W2'][0][0] + (error * A1[0][0]).item()
    parameters['W2'][0][1] = parameters['W2'][0][1] + (error * A1[1][0]).item()
    parameters['b2'][0][0] = parameters['b2'][0][0] + error
    
    parameters['W1'][0][0] = parameters['W1'][0][0] + (error * parameters['W2'][0][0] * X[0][0]).item()
    parameters['W1'][1][0] = parameters['W1'][1][0] + (error * parameters['W2'][0][0] * X[1][0]).item()
    parameters['b1'][0][0] = parameters['b1'][0][0] + (error * parameters['W2'][0][0]).item()
    
    parameters['W1'][0][1] = parameters['W1'][0][1] + (error * parameters['W2'][0][1] * X[0][0]).item()
    parameters['W1'][1][1] = parameters['W1'][1][1] + (error * parameters['W2'][0][1] * X[1][0]).item()      
    parameters['b1'][1][0] = parameters['b1'][1][0] + (error * parameters['W2'][0][1]).item()

# %%
update_parameters(parameters, y, y_hat,A1,X)

# %%
parameters
# Out:
# {'W1': array([[0.10658137, 0.10658137],
#         [0.10658137, 0.10658137]]),
#  'b1': array([[0.00082267],
#         [0.00082267]]),
#  'W2': array([[0.111776, 0.111776]]),
#  'b2': array([[0.00736]])}

# %%
X = df[['cgpa', 'profile_score']].values[2].reshape(2,1)
y = df[['lpa']].values[2][0]

y_hat,A1 = L_layer_forward(X, parameters)
# Out:
# A0:  [[ 6]
#  [10]]
# W1:  [[0.10658137 0.10658137]
#  [0.10658137 0.10658137]]
# b1:  [[0.00082267]
#  [0.00082267]]
# ----------------------------------------
# A1:  [[1.70612461]
#  [1.70612461]]
# A1:  [[1.70612461]
#  [1.70612461]]
# W2:  [[0.111776 0.111776]]
# b2:  [[0.00736]]
# ----------------------------------------
# A2:  [[0.38876757]]

# %%
# epochs implemenation

parameters = initialize_parameters([2,2,1])
epochs = 5

for i in range(epochs):
    loss = []

    for j in range(df.shape[0]):
        X = df[['cgpa', 'profile_score']].values[j].reshape(2,1)
        y = df[['lpa']].values[j][0]

        y_hat,A1 = L_layer_forward(X, parameters)
        loss.append((y - y_hat[0][0])**2)

        update_parameters(parameters, y, y_hat,A1,X)

        loss.append((y - y_hat[0][0])**2)

    print('Epoch: ', i+1, ' Loss: ', np.array(loss).mean())
parameters
# Out:
# A0:  [[8]
#  [8]]
# W1:  [[0.1 0.1]
#  [0.1 0.1]]
# b1:  [[0.]
#  [0.]]
# ----------------------------------------
# A1:  [[1.6]
#  [1.6]]
# A1:  [[1.6]
#  [1.6]]
# W2:  [[0.1 0.1]]
# b2:  [[0.]]
# ----------------------------------------
# A2:  [[0.32]]
# A0:  [[7]
#  [9]]
# W1:  [[0.10658137 0.10658137]
#  [0.10658137 0.10658137]]
# b1:  [[0.00082267]
#  [0.00082267]]
# ----------------------------------------
# A1:  [[1.70612461]
#  [1.70612461]]
# A1:  [[1.70612461]
#  [1.70612461]]
# W2:  [[0.111776 0.111776]]
# b2:  [[0.00736]]
# ----------------------------------------
# A2:  [[0.38876757]]
# A0:  [[ 6]
#  [10]]
# W1:  [[0.11481311 0.11481311]
#  [0.11716504 0.11716504]]
# b1:  [[0.00199863]
#  [0.00199863]]
# ----------------------------------------
# A1:  [[1.83900839]
#  [1.8766392 ]]
# A1:  [[1.83900839]
#  [1.8766392 ]]
# W2:  [[0.12751067 0.12751067]]
# b2:  [[0.01658246]]
# ----------------------------------------
# A2:  [[0.49036719]]
# A0:  [[ 5]
#  [12]]
# W1:  [[0.12458335 0.12461077]
#  [0.13344878 0.13349447]]
# b1:  [[0.00362701]
#  [0.00363158]]
# ----------------------------------------
# A1:  [[2.12187303]
#  [2.2728091 ]]
# A1:  [[2.12187303]
#  [2.2728091 ]]
# W2:  [[0.1477752  0.14818986]]
# b2:  [[0.02760173]]
# ----------------------------------------
# A2:  [[0.6779692]]
# Epoch:  1  Loss:  26.28249792398698
# A0:  [[8]
#  [8]]
# W1:  [[0.13562189 0.13579618]
#  [0.15994127 0.16033944]]
# b1:  [[0.00583472]
#  [0.00586866]]
# ----------------------------------------
# A1:  [[2.17717925]
#  [2.56811431]]
# A1:  [[2.17717925]
#  [2.56811431]]
# W2:  [[0.17460429 0.1769274 ]]
# b2:  [[0.04024579]]
# ----------------------------------------
# A2:  [[0.87476041]]
# A0:  [[7]
#  [9]]
# W1:  [[0.14503325 0.14544588]
#  [0.16935262 0.16998915]]
# b1:  [[0.00701114]
#  [0.00707487]]
# ----------------------------------------
# A1:  [[2.33125681]
#  [2.72244555]]
# A1:  [[2.33125681]
#  [2.72244555]]
# W2:  [[0.1882127  0.19297934]]
# b2:  [[0.04649627]]
# ----------------------------------------
# A2:  [[1.01064417]]
# A0:  [[ 6]
#  [10]]
# W1:  [[0.15658396 0.15743714]
#  [0.18420354 0.18540648]]
# b1:  [[0.00866124]
#  [0.00878791]]
# ----------------------------------------
# A1:  [[2.52253643]
#  [2.96807397]]
# A1:  [[2.52253643]
#  [2.96807397]]
# W2:  [[0.20681313 0.21470095]]
# b2:  [[0.05447498]]
# ----------------------------------------
# A2:  [[1.21341694]]
# A0:  [[ 5]
#  [12]]
# W1:  [[0.16985018 0.17140141]
#  [0.2063139  0.20868027]]
# b1:  [[0.01087227]
#  [0.01111529]]
# ----------------------------------------
# A1:  [[2.91694011]
#  [3.54684797]]
# A1:  [[2.91694011]
#  [3.54684797]]
# W2:  [[0.23096179 0.24311482]]
# b2:  [[0.06404815]]
# ----------------------------------------
# A2:  [[1.60004115]]
# Epoch:  2  Loss:  19.438253848220803
# A0:  [[8]
#  [8]]
# W1:  [[0.18402315 0.186598  ]
#  [0.24032904 0.24515208]]
# b1:  [[0.01370687]
#  [0.01415461]]
# ----------------------------------------
# A1:  [[2.97867611]
#  [3.89800358]]
# A1:  [[2.97867611]
#  [3.89800358]]
# W2:  [[0.2624645  0.28142048]]
# b2:  [[0.07484807]]
# ----------------------------------------
# A2:  [[1.95362286]]
# A0:  [[7]
#  [9]]
# W1:  [[0.19301593 0.19633463]
#  [0.24932182 0.25488871]]
# b1:  [[0.01483097]
#  [0.01537168]]
# ----------------------------------------
# A1:  [[3.1329542 ]
#  [4.05462284]]
# A1:  [[3.1329542 ]
#  [4.05462284]]
# W2:  [[0.27465549 0.29737405]]
# b2:  [[0.07894082]]
# ----------------------------------------
# A2:  [[2.14516353]]
# A0:  [[ 6]
#  [10]]
# W1:  [[0.20470823 0.20914527]
#  [0.26435477 0.27135953]]
# b1:  [[0.01650129]
#  [0.01720178]]
# ----------------------------------------
# A1:  [[3.33620338]
#  [4.31692573]]
# A1:  [[3.33620338]
#  [4.31692573]]
# W2:  [[0.29254364 0.32052462]]
# b2:  [[0.08465049]]
# ----------------------------------------
# A2:  [[2.44431656]]
# A0:  [[ 5]
#  [12]]
# W1:  [[0.21820284 0.22413136]
#  [0.2868458  0.29633635]]
# b1:  [[0.0187504 ]
#  [0.01969946]]
# ----------------------------------------
# A1:  [[3.79934094]
#  [5.00996462]]
# A1:  [[3.79934094]
#  [5.00996462]]
# W2:  [[0.3162686  0.35122387]]
# b2:  [[0.09176186]]
# ----------------------------------------
# A2:  [[3.05299325]]
# Epoch:  3  Loss:  10.13987443582752
# A0:  [[8]
#  [8]]
# W1:  [[0.23186978 0.23955518]
#  [0.31964643 0.33335352]]
# b1:  [[0.02148378]
#  [0.02278422]]
# ----------------------------------------
# A1:  [[3.79288343]
#  [5.24678381]]
# A1:  [[3.79288343]
#  [5.24678381]]
# W2:  [[0.34626065 0.39077259]]
# b2:  [[0.09965587]]
# ----------------------------------------
# A2:  [[3.46328148]]
# A0:  [[7]
#  [9]]
# W1:  [[0.23487825 0.2429593 ]
#  [0.32265491 0.33675764]]
# b1:  [[0.02185984]
#  [0.02320974]]
# ----------------------------------------
# A1:  [[3.85264134]
#  [5.31261285]]
# A1:  [[3.85264134]
#  [5.31261285]]
# W2:  [[0.35033207 0.39640469]]
# b2:  [[0.10072931]]
# ----------------------------------------
# A2:  [[3.55637777]]
# A0:  [[ 6]
#  [10]]
# W1:  [[0.24218353 0.25128093]
#  [0.3320474  0.34745688]]
# b1:  [[0.02290345]
#  [0.02439854]]
# ----------------------------------------
# A1:  [[3.98881394]
#  [5.49125174]]
# A1:  [[3.98881394]
#  [5.49125174]]
# W2:  [[0.36145559 0.4117435 ]]
# b2:  [[0.10361656]]
# ----------------------------------------
# A2:  [[3.80638285]]
# A0:  [[ 5]
#  [12]]
# W1:  [[0.25215892 0.26275359]
#  [0.34867307 0.36657798]]
# b1:  [[0.02456602]
#  [0.02631065]]
# ----------------------------------------
# A1:  [[4.43840374]
#  [6.16861171]]
# A1:  [[4.43840374]
#  [6.16861171]]
# W2:  [[0.37895545 0.43583491]]
# b2:  [[0.10800379]]
# ----------------------------------------
# A2:  [[4.47845739]]
# Epoch:  4  Loss:  3.385561305106485
# A0:  [[8]
#  [8]]
# W1:  [[0.26227885 0.27452778]
#  [0.37296089 0.39483602]]
# b1:  [[0.02659   ]
#  [0.02866549]]
# ----------------------------------------
# A1:  [[4.32104303]
#  [6.17104077]]
# A1:  [[4.32104303]
#  [6.17104077]]
# W2:  [[0.4013387  0.46694374]]
# b2:  [[0.11304688]]
# ----------------------------------------
# A2:  [[4.72877753]]
# A0:  [[7]
#  [9]]
# W1:  [[0.2576725  0.26918789]
#  [0.36835454 0.38949613]]
# b1:  [[0.02601421]
#  [0.027998  ]]
# ----------------------------------------
# A1:  [[4.25241274]
#  [6.111945  ]]
# A1:  [[4.25241274]
#  [6.111945  ]]
# W2:  [[0.39504054 0.45794911]]
# b2:  [[0.11158932]]
# ----------------------------------------
# A2:  [[4.59042452]]
# A0:  [[ 6]
#  [10]]
# W1:  [[0.25995766 0.2718425 ]
#  [0.3712926  0.39290921]]
# b1:  [[0.02634066]
#  [0.02837723]]
# ----------------------------------------
# A1:  [[4.30451167]
#  [6.18522495]]
# A1:  [[4.30451167]
#  [6.18522495]]
# W2:  [[0.39852391 0.46295572]]
# b2:  [[0.11240847]]
# ----------------------------------------
# A2:  [[4.69134453]]
# A0:  [[ 5]
#  [12]]
# W1:  [[0.26639295 0.27936692]
#  [0.38201809 0.40544991]]
# b1:  [[0.02741321]
#  [0.0296313 ]]
# ----------------------------------------
# A1:  [[4.71178104]
#  [6.80512062]]
# A1:  [[4.71178104]
#  [6.80512062]]
# W2:  [[0.40979015 0.47914437]]
# b2:  [[0.11502578]]
# ----------------------------------------
# A2:  [[5.30650251]]
# Epoch:  5  Loss:  1.3198454128484565
# {'W1': array([[0.273603  , 0.28787155],
#         [0.3993222 , 0.42586102]]),
#  'b1': array([[0.02885522],
#         [0.03133223]]),
#  'W2': array([[0.42574893, 0.50219328]]),
#  'b2': array([[0.11841278]])}
